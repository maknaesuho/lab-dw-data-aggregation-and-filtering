# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
url= 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
marketing_customer_analysis = pd.read_csv(url)

# %%
marketing_customer_analysis
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who:
#    - have a **low total_claim_amount** (e.g., below $1,000),
#    - have a response "Yes" to the last marketing campaign.

# %%
mask = (marketing_customer_analysis["total_claim_amount"] < 1000) & (marketing_customer_analysis["response"] == "Yes")
low_claim_amount = marketing_customer_analysis[mask]

# %%
low_claim_amount.sort_values(by = "total_claim_amount", ascending = False)
# Out:
#       unnamed:_0 customer       state  customer_lifetime_value response  \
# 3338        3338  AM26717  California              3123.080994      Yes
# 3558        3558  ST96866  Washington              3123.080994      Yes
# 4414        4414  JW24212      Oregon              3123.080994      Yes
# 7492        7492  YS74016  California              3123.080994      Yes
# 8377        8377  NT76210      Nevada              3123.080994      Yes
# ...          ...      ...         ...                      ...      ...
# 2792        2792  CJ81799      Oregon              7462.926263      Yes
# 7886        7886  EZ70589  Washington              7462.926263      Yes
# 9131        9131  TR81766  California              7462.926263      Yes
# 2400        2400  GJ99406     Arizona              7462.926263      Yes
# 144          144  NR16284  California              7462.926263      Yes
#
#       coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze:
#    - the average `monthly_premium` and/or customer lifetime value by `policy_type` and `gender` for customers who responded "Yes", and
#    - compare these insights to `total_claim_amount` patterns, and discuss which segments appear most profitable or low-risk for the company.

# %%
marketing_customer_analysis.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='str')

# %%
grouped = marketing_customer_analysis.groupby('response')

# %%
yes = grouped.get_group("Yes")

# %%
yes.groupby(["policy_type", "gender"])[["monthly_premium_auto", "customer_lifetime_value", "total_claim_amount"]].mean().round(2)
# Out:
#                        monthly_premium_auto  customer_lifetime_value  \
# policy_type    gender
# Corporate Auto F                      94.30                  7712.63
#                M                      92.19                  7944.47
# Personal Auto  F                      99.00                  8339.79
#                M                      91.09                  7448.38
# Special Auto   F                      92.31                  7691.58
#                M                      86.34                  8247.09
#
#                        total_claim_amount
# policy_type    gender
# Corporate Auto F                   433.74
#                M                   408.58
# Personal Auto  F                   452.97
#                M                   457.01
# Special Auto   F                   453.28
#                M                   429.53

# %% [markdown]
# Compare these insights to total_claim_amount patterns, and discuss which segments appear most profitable or low-risk for the company.

# %% [markdown]
# - Most Profitable: Personal Auto (Female) generates the highest monthly premium (98.99) and lifetime value (8,339.79), easily absorbing claims (452.97).
# - Lowest Risk: Corporate Auto (Male) delivers the lowest claim amount (408.58) alongside stable premium revenue (92.19).
# - Consistent: Corporate Auto (Female) similarly exhibits well-managed claim levels (433.74) with steady premiums (94.30).
# - Highest Risk: Personal Auto (Male) presents the narrowest margins, pairing peak claim severity (457.01) with the lowest customer lifetime value (7,448.38).

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
policy_num = marketing_customer_analysis["number_of_policies"] > 0
filtered = marketing_customer_analysis[policy_num]
state_count = filtered.groupby("state")["customer"].count()

# %%
more_than500 = (state_count[state_count > 500])

# %%
more_than500
# Out:
# state
# Arizona       1937
# California    4183
# Nevada         993
# Oregon        2909
# Washington     888
# Name: customer, dtype: int64

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
marketing_customer_analysis.groupby(['education', 'gender'])['customer_lifetime_value'].agg(['max', 'min', 'median']).round(2)
# Out:
#                                   max      min   median
# education            gender
# Bachelor             F       73225.96  1904.00  5640.51
#                      M       67907.27  1898.01  5548.03
# College              F       61850.19  1898.68  5623.61
#                      M       61134.68  1918.12  6005.85
# Doctor               F       44856.11  2395.57  5332.46
#                      M       32677.34  2267.60  5577.67
# High School or Below F       55277.45  2144.92  6039.55
#                      M       83325.38  1940.98  6286.73
# Master               F       51016.07  2417.78  5729.86
#                      M       50568.26  2272.31  5579.10

# %% [markdown]
# - Stable Medians: Typical customer lifetime value is nearly identical across all groups, hovering between 5,300 and 6,300 regardless of education or gender.
# - Highest Spenders: The biggest individual values appear in High School or Below (Male) at 83,325 and Bachelor (Female) at 73,226.
# - Advanced Degrees Cap Out Lower: Customers with a Master or Doctor degree reach much lower maximums, peaking between roughly 32,600 and 51,000.
# - Equal Baseline: Minimum values stay uniform across every tier at around 1,900 to 2,400.
# - Main Takeaway: Higher academic education does not lead to higher customer lifetime value.

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
